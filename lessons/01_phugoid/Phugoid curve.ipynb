# %%
# %run phugoid.py
# %matplotlib inline
import matplotlib
import numpy

# %%
# zt = 64, zeta = 16, theta = 0
plot_flight_path(64,16,0)

# %%
plot_flight_path(96,7.62,numpy.pi)

# %%
plot_flight_path(16,48,0.)

# %%
plot_flight_path(64,16,-numpy.pi/2)
